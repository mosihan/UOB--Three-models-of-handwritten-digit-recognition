# %% [markdown]
# <a href="https://colab.research.google.com/github/mosihan/UOB--Three-models-of-handwritten-digit-recognition/blob/main/Last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LR

# %%
# %reset
# %who

# %%
import numpy as np
import pandas as pd

# Loading MINIST dataset
import tensorflow
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Vectoring: reshape 3d to 2d matrixes 
X_train=train_images.reshape(60000,-1)
X_test=test_images.reshape(10000,-1)
y_train=train_labels
y_test=test_labels

# %%
import datetime
start = datetime.datetime.now()

from sklearn.linear_model import LogisticRegression

LR1 = LogisticRegression(C=1.0,max_iter=70)
LR1.fit(X_train, y_train)

end = datetime.datetime.now()
print (end-start)
# Out:
# 0:00:33.475093
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
from sklearn import metrics
y_test_pred1=LR1.predict(X_test)
print(metrics.classification_report(y_test, y_test_pred1,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9570    0.9776    0.9672       980
#            1     0.9670    0.9806    0.9738      1135
#            2     0.9307    0.8973    0.9137      1032
#            3     0.9022    0.9139    0.9080      1010
#            4     0.9326    0.9297    0.9312       982
#            5     0.8943    0.8632    0.8785       892
#            6     0.9391    0.9499    0.9445       958
#            7     0.9325    0.9270    0.9298      1028
#            8     0.8675    0.8809    0.8742       974
#            9     0.9089    0.9098    0.9094      1009
#
#     accuracy                         0.9242     10000
#    macro avg     0.9232    0.9230    0.9230     10000
# weighted avg     0.9241    0.9242    0.9241     10000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
disp = metrics.plot_confusion_matrix(LR1, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
# Out:
# Confusion matrix:
# [[ 958    0    1    3    0    8    6    3    1    0]
#  [   0 1113    3    3    0    1    4    2    9    0]
#  [   5   11  926   16    7    3   13    9   38    4]
#  [   4    1   17  923    0   23    3   10   23    6]
#  [   1    1    7    2  913    0    8    4   10   36]
#  [   8    1    4   37   10  770   14    6   35    7]
#  [   9    3    7    1    8   15  910    3    2    0]
#  [   1    6   23    4    7    1    0  953    4   29]
#  [   5    8    6   24    7   34   11   11  858   10]
#  [  10    7    1   10   27    6    0   21    9  918]]

# %% [markdown]
# #SVM-first

# %%
# %reset
# %who
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? Y
# Interactive namespace is empty.

# %%
import numpy as np
import pandas as pd

# Loading MINIST dataset
import tensorflow
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Vectoring: reshape 3d to 2d matrixes 
X_train=train_images.reshape(60000,-1)
X_test=test_images.reshape(10000,-1)
y_train=train_labels
y_test=test_labels

# %%
import datetime
start = datetime.datetime.now()

from sklearn import svm
svm1 = svm.SVC(C=4.3)
svm1.fit(X_train, y_train)

end = datetime.datetime.now()
print (end-start)
# Out:
# 0:08:13.424861

# %%
from sklearn import metrics
y_test_pred1 = svm1.predict(X_test)
print(metrics.classification_report(y_test, y_test_pred1,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9858    0.9929    0.9893       980
#            1     0.9921    0.9947    0.9934      1135
#            2     0.9778    0.9816    0.9797      1032
#            3     0.9803    0.9861    0.9832      1010
#            4     0.9827    0.9857    0.9842       982
#            5     0.9865    0.9798    0.9831       892
#            6     0.9916    0.9896    0.9906       958
#            7     0.9815    0.9786    0.9800      1028
#            8     0.9845    0.9774    0.9809       974
#            9     0.9771    0.9722    0.9747      1009
#
#     accuracy                         0.9840     10000
#    macro avg     0.9840    0.9839    0.9839     10000
# weighted avg     0.9840    0.9840    0.9840     10000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
disp = metrics.plot_confusion_matrix(svm1, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
# Out:
# Confusion matrix:
# [[ 973    0    2    0    0    2    0    1    2    0]
#  [   0 1129    2    1    0    1    0    1    1    0]
#  [   5    1 1013    0    1    0    1    6    4    1]
#  [   0    0    3  996    0    2    0    3    3    3]
#  [   0    0    4    0  968    0    2    0    0    8]
#  [   2    0    0    7    1  874    3    0    3    2]
#  [   3    2    0    0    2    2  948    0    1    0]
#  [   0    4   10    2    1    0    0 1006    0    5]
#  [   3    0    2    4    3    3    1    2  952    4]
#  [   1    2    0    6    9    2    1    6    1  981]]

# %% [markdown]
# #BPNN-first

# %%
# %reset
# %who
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Interactive namespace is empty.

# %%
import numpy as np
import pandas as pd

# Loading MINIST dataset
import tensorflow
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Vectoring: reshape 3d to 2d matrixes 
X_train=train_images.reshape(60000,-1)
X_test=test_images.reshape(10000,-1)
y_train=train_labels
y_test=test_labels

# %%
import datetime
start = datetime.datetime.now()

from sklearn.neural_network import MLPClassifier
bpnn1 = MLPClassifier(hidden_layer_sizes=(300, ),max_iter=150)
bpnn1.fit(X_train, y_train)

end = datetime.datetime.now()
print (end-start)
# Out:
# 0:04:45.820969

# %%
from sklearn import metrics
y_test_pred1 = bpnn1.predict(X_test)
print(metrics.classification_report(y_test, y_test_pred1,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9799    0.9929    0.9863       980
#            1     0.9938    0.9894    0.9916      1135
#            2     0.9575    0.9826    0.9699      1032
#            3     0.9807    0.9545    0.9674      1010
#            4     0.9884    0.9511    0.9694       982
#            5     0.9751    0.9675    0.9713       892
#            6     0.9884    0.9791    0.9837       958
#            7     0.9822    0.9660    0.9740      1028
#            8     0.9538    0.9754    0.9645       974
#            9     0.9418    0.9792    0.9602      1009
#
#     accuracy                         0.9740     10000
#    macro avg     0.9742    0.9738    0.9738     10000
# weighted avg     0.9743    0.9740    0.9740     10000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
disp = metrics.plot_confusion_matrix(bpnn1, X_test, y_test)
disp.figure_.suptitle("Confusion Matrix for BP neural network")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
# Out:
# Confusion matrix:
# [[ 973    0    1    0    0    0    2    1    3    0]
#  [   1 1123    5    0    0    1    1    0    4    0]
#  [   4    0 1014    1    3    0    0    3    4    3]
#  [   0    0    8  964    0   13    0    7   12    6]
#  [   0    0    6    0  934    0    2    0    3   37]
#  [   2    0    0    8    2  863    5    3    7    2]
#  [   5    3    0    1    2    2  938    0    7    0]
#  [   1    1   17    3    1    0    0  993    3    9]
#  [   4    0    8    4    1    0    1    2  950    4]
#  [   3    3    0    2    2    6    0    2    3  988]]
